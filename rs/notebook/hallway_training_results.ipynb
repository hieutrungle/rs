# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import os

# %% [markdown]
# ## Comparison training_results with 2 users

# %%
ppo_2ue = {
    
    "random": {
        "res_0": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_random/res_0.txt",
        "res_1": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_random/res_1.txt",
        "res_2": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_random/res_2.txt",
    },
    "no_allocator": {
        "res_0": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_no_allocator/res_0.txt",
        "res_1": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_no_allocator/res_1.txt",
        "res_2": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_no_allocator/res_2.txt",
    },
    "no_compat": {
        "res_0": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_no_compat/res_0.txt",
        "res_1": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_no_compat/res_1.txt",
        "res_2": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_no_compat/res_2.txt",
    },
    "allocator": {
        "res_0": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_allocator/res_0.txt",
        "res_1": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_allocator/res_1.txt",
        "res_2": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_allocator/res_2.txt",
        "res_3": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_allocator/res_3.txt",
        "res_4": "/home/hieule/research/rs/local_assets/training_results/ppo_2ue_allocator/res_4.txt",
    },
}

# %%
# get lines with "episode_reward_mean = ..."
def get_episode_rewards(file_path):
    # print(f"Processing file: {file_path}")
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    rewards = []
    for line in lines:
        if "episode_reward_mean" in line:
            parts = line.split(" ")
            reward = float(parts[2][:-1])
            rewards.append(reward)
    return rewards

def plot_rewards(ppo_data, title):
    plt.figure(figsize=(10, 6))
    lines = []
    for label, files in ppo_data.items():
        all_rewards = []
        for file in files.values():
            rewards = get_episode_rewards(file)
            rewards = np.array(rewards)
            print(f"file: {file}, rewards: {rewards.shape}")
            all_rewards.append(rewards)
            
        
        # Average rewards across runs
        avg_rewards = np.mean(all_rewards, axis=0)
        std_rewards = np.std(all_rewards, axis=0)
        episodes = np.arange(len(avg_rewards)) * 20
        line, = plt.plot(episodes, avg_rewards, label=label)
        lines.append(line)
        plt.fill_between(episodes, avg_rewards - std_rewards, avg_rewards + std_rewards, alpha=0.2)
    
    plt.title(title, fontsize=16)
    plt.xlabel('Episode', fontsize=14)
    plt.ylabel('Average Reward', fontsize=14)
    # reverse the order of names of legends
    handles, labels = plt.gca().get_legend_handles_labels()
    order = [3, 2, 1, 0]
    plt.legend([handles[i] for i in order], [labels[i] for i in order], fontsize=12, loc='lower right')
    plt.grid()
    
    # larger font size
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.tight_layout()
    plt.show()

# %%
# Plotting the results
plot_rewards(ppo_2ue, "Training Results Comparison of the Scenario with 2 Users")
# Out:
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_random/res_0.txt, rewards: (153,)
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_random/res_1.txt, rewards: (153,)
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_random/res_2.txt, rewards: (153,)
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_no_allocator/res_0.txt, rewards: (153,)
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_no_allocator/res_1.txt, rewards: (153,)
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_no_allocator/res_2.txt, rewards: (153,)
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_no_compat/res_0.txt, rewards: (153,)
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_no_compat/res_1.txt, rewards: (153,)
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_no_compat/res_2.txt, rewards: (153,)
# file: /home/hieule/research/rs/local_assets/results/ppo_2ue_allocator/res_0.txt, rewards: (153,)
# ...

# %% [markdown]
# ## Comparison training_results with 4 users

# %%
ppo_4ue = {
    
    "random": {
        "res_0": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_random/res_0.txt",
        "res_1": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_random/res_1.txt",
        "res_2": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_random/res_2.txt",
    },
    "no_allocator": {
        "res_0": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_no_allocator/res_0.txt",
        "res_1": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_no_allocator/res_1.txt",
        "res_2": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_no_allocator/res_2.txt",
    },
    "no_compat": {
        "res_0": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_no_compat/res_0.txt",
        "res_1": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_no_compat/res_1.txt",
        "res_2": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_no_compat/res_2.txt",
    },
    "allocator": {
        "res_0": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_allocator/res_0.txt",
        "res_1": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_allocator/res_1.txt",
        "res_2": "/home/hieule/research/rs/local_assets/training_results/ppo_4ue_allocator/res_2.txt",
    },
}

# Plotting the training_results
plot_rewards(ppo_4ue, "Training Results Comparison of the Scenario with 4 Users")
# Out:
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_random/res_0.txt, rewards: (152,)
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_random/res_1.txt, rewards: (152,)
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_random/res_2.txt, rewards: (152,)
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_no_allocator/res_0.txt, rewards: (152,)
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_no_allocator/res_1.txt, rewards: (152,)
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_no_allocator/res_2.txt, rewards: (152,)
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_no_compat/res_0.txt, rewards: (152,)
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_no_compat/res_1.txt, rewards: (152,)
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_no_compat/res_2.txt, rewards: (152,)
# file: /home/hieule/research/rs/local_assets/results/ppo_4ue_allocator/res_0.txt, rewards: (152,)
# ...
